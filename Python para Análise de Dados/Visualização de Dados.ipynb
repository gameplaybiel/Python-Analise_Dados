# %% [markdown]
# # Vusualização de dados com Matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(7)
# Vetor com números inteiros aleatórios entre 1,1500, com 10 números

y = np.random.randint(low = 1, high = 1500, size = 10)
y

# %%
plt.plot(y)

# %%
data = np.random.normal(10, 0.5, 5000)
plt.hist(data)
plt.show()

# %%
plt.boxplot(data)

# %% [markdown]
# **Scatter plot**

# %%
x = np.random.normal(10, 0.5, 100)
y = np.random.uniform(0, 20, 100)

# %% [markdown]
# **Dados econômicos**

# %%
import plotly.express as px

# %%
px.data.gapminder()

# %%
df = px.data.gapminder().query('country == "Brasil"').set_index('year')
df.head()
