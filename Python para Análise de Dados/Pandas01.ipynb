# %%
#Pandas

# Biblioteca para a modelagem de dados
import pandas as pd

#Biblioteca para recursos matemáticos
import numpy as np

# Biblioteca para plotagem de dados
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
#Lista com os rótulos
Labels = ['1º', '2°', '3°']

#Lista com valores
Valores = [10, 20, 30]

#Criando a base de dados com as linhas
Serie = pd.Series(data=Valores, index=Labels)
Serie
# Out:
# 1º    10
# 2°    20
# 3°    30
# dtype: int64

# %%
Serie['1º']
# Out:
# 10

# %%
Serie * 2
# Out:
# 1º    20
# 2°    40
# 3°    60
# dtype: int64

# %%
Serie_Nova = pd.Series(data=[50,100,150], index=Labels)
Serie + Serie_Nova
# Out:
# 1º     60
# 2°    120
# 3°    180
# dtype: int64

# %%
#Criando um dicionário
Dicionario = {
    'A': [1, 2, 3],
    'B': [-3, -2, -1],
    'C': [0, 10, 20] }

#Criando uma lista com os labels
Labels = ['1ºLinha', '2ºLinha', '3ºLinha']

DataFrame_01 = pd.DataFrame(Dicionario, index=Labels)
DataFrame_01
# Out:
#          A  B   C
# 1ºLinha  1 -3   0
# 2ºLinha  2 -2  10
# 3ºLinha  3 -1  20

# %%
DataFrame_01['Nova Coluna'] = DataFrame_01['A'] * DataFrame_01['B']
DataFrame_01
# Out:
#          A  B   C  Nova Coluna
# 1ºLinha  1 -3   0           -3
# 2ºLinha  2 -2  10           -4
# 3ºLinha  3 -1  20           -3

# %%
DataFrame_01.drop('Nova Coluna', axis=1, inplace=True)
DataFrame_01
# Out:
#          A  B   C
# 1ºLinha  1 -3   0
# 2ºLinha  2 -2  10
# 3ºLinha  3 -1  20

# %%
DataFrame_01.loc[['1ºLinha', '3ºLinha'], ['A', 'C']]
# Out:
#          A   C
# 1ºLinha  1   0
# 3ºLinha  3  20

# %%
DataFrame_01.iloc[0:3, 1:]
# Out:
#          B   C
# 1ºLinha -3   0
# 2ºLinha -2  10
# 3ºLinha -1  20

# %%
DataFrame_01 > 0
# Out:
#             A      B      C
# 1ºLinha  True  False  False
# 2ºLinha  True  False   True
# 3ºLinha  True  False   True

# %%
DataFrame_01[DataFrame_01['A'] > 0]['C']
# Out:
# 1ºLinha     0
# 2ºLinha    10
# 3ºLinha    20
# Name: C, dtype: int64

# %%
Filtro = DataFrame_01['C'] > 0
DataFrame_02 = DataFrame_01[Filtro]
DataFrame_02['A']
# Out:
# 2ºLinha    2
# 3ºLinha    3
# Name: A, dtype: int64

# %%
DataFrame_01[
    (DataFrame_01['A'] > 1 ) & (DataFrame_01['C'] > 0)
]
# Out:
#          A  B   C
# 2ºLinha  2 -2  10
# 3ºLinha  3 -1  20

# %%
DataFrame_01.reset_index()
# Out:
#      index  A  B   C
# 0  1ºLinha  1 -3   0
# 1  2ºLinha  2 -2  10
# 2  3ºLinha  3 -1  20

# %%
DataFrame_01
# Out:
#          A  B   C
# 1ºLinha  1 -3   0
# 2ºLinha  2 -2  10
# 3ºLinha  3 -1  20

# %%
#Criando vários dicionários
Dicionario_01 = {'A': [1, 2, 3],
                 'B': [-32, -21, -15],
                 'C': [60, 10, 20]
                 }

Dicionario_02 = {'D:': [6, 7, 8],
                 'E': [-39, -28, -17],
                 'F': [1000, 10, 60]}

#Criando várias listas para serem os labels
Label_01 = ['1ºLinha', '2ºLinha', '3ºLinha']

# Estruturando as bases de dados
DataFrame_01 = pd.DataFrame(Dicionario_01, index=Label_01)
DataFrame_02 = pd.DataFrame(Dicionario_02, index=Label_01)

#Aplicando a função join
DataFrame_01.join(DataFrame_02)
# Out:
#          A   B   C  D:   E     F
# 1ºLinha  1 -32  60   6 -39  1000
# 2ºLinha  2 -21  10   7 -28    10
# 3ºLinha  3 -15  20   8 -17    60

# %%
DataFrame_01.describe()
# Out:
#          A          B          C
# count  3.0   3.000000   3.000000
# mean   2.0 -22.666667  30.000000
# std    1.0   8.621678  26.457513
# min    1.0 -32.000000  10.000000
# 25%    1.5 -26.500000  15.000000
# 50%    2.0 -21.000000  20.000000
# 75%    2.5 -18.000000  40.000000
# max    3.0 -15.000000  60.000000

# %%
DataFrame_02.describe()
# Out:
#         D:     E            F
# count  3.0   3.0     3.000000
# mean   7.0 -28.0   356.666667
# std    1.0  11.0   557.703625
# min    6.0 -39.0    10.000000
# 25%    6.5 -33.5    35.000000
# 50%    7.0 -28.0    60.000000
# 75%    7.5 -22.5   530.000000
# max    8.0 -17.0  1000.000000
